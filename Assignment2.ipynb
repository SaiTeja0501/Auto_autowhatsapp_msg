# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiTeja0501/Auto_autowhatsapp_msg/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DATA : NBA players data set

# %% [markdown]
# ## 1. Importing the libraries

# %%
import warnings
warnings.simplefilter("ignore")

# %%
import numpy  as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 2 . Importing the data

# %%
dataset = pd.read_csv("/content/nba_Player data.csv")

# %%
dataset
# Out:
#                 Player Position  Age  Games  Minutes Played  True Shooting(%)  \
# 0     Precious Achiuwa       PF   21     28           408.0             0.599
# 1         Jaylen Adams       PG   24      6            17.0             0.125
# 2         Steven Adams        C   27     27           760.0             0.592
# 3          Bam Adebayo        C   23     26           873.0             0.641
# 4    LaMarcus Aldridge        C   35     18           480.0             0.542
# ..                 ...      ...  ...    ...             ...               ...
# 492       Delon Wright       SG   28     28           823.0             0.559
# 493     Thaddeus Young       PF   32     23           592.0             0.597
# 494         Trae Young       PG   22     26           901.0             0.598
# 495        Cody Zeller        C   28     15           361.0             0.569
# 496        Ivica Zubac        C   23     30           586.0             0.722
#
# ...

# %%
dataset.head(10)
# Out:
#                      Player Position  Age  Games  Minutes Played  \
# 0          Precious Achiuwa       PF   21     28           408.0
# 1              Jaylen Adams       PG   24      6            17.0
# 2              Steven Adams        C   27     27           760.0
# 3               Bam Adebayo        C   23     26           873.0
# 4         LaMarcus Aldridge        C   35     18           480.0
# 5         Ty-Shon Alexander       SG   22      3             8.0
# 6  Nickeil Alexander-Walker       SG   22     23           441.0
# 7             Grayson Allen       SG   25     19           454.0
# 8             Jarrett Allen        C   22     28           734.0
# 9             Jarrett Allen        C   22     12           320.0
#
#    True Shooting(%)  Threepoint Attempt rate  Free throw attempt rate  \
# 0             0.599                    0.000                    0.541
# 1             0.125                    0.250                    0.000
# ...

# %% [markdown]
# ### checking the null values

# %%
dataset.isnull()
# Out:
#      Player  Position    Age  Games  Minutes Played  True Shooting(%)  \
# 0     False     False  False  False           False             False
# 1     False     False  False  False           False             False
# 2     False     False  False  False           False             False
# 3     False     False  False  False           False             False
# 4     False     False  False  False           False             False
# ..      ...       ...    ...    ...             ...               ...
# 492   False     False  False  False           False             False
# 493   False     False  False  False           False             False
# 494   False     False  False  False           False             False
# 495   False     False  False  False           False             False
# 496   False     False  False  False           False             False
#
#      Threepoint Attempt rate  Free throw attempt rate  \
# 0                      False                    False
# ...

# %%
dataset.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              2
# True Shooting(%)            3
# Threepoint Attempt rate     2
# Free throw attempt rate     2
# Player Efficiency Rating    0
# dtype: int64

# %%
dataset.fillna(value = 0,
          inplace = True)

# %%
dataset.isnull().sum()
# Out:
# Player                      0
# Position                    0
# Age                         0
# Games                       0
# Minutes Played              0
# True Shooting(%)            0
# Threepoint Attempt rate     0
# Free throw attempt rate     0
# Player Efficiency Rating    0
# dtype: int64

# %% [markdown]
# ## 3.Visualizing the data

# %%
#Make a pairwise scatter plot
sns.pairplot(dataset[["Games","Minutes Played","True Shooting(%)", "Threepoint Attempt rate", "Free throw attempt rate"]])

# %%
dataset.plot.scatter(x ='Free throw attempt rate', y ='Player Efficiency Rating')

# %%
dataset.plot.scatter(x ='Threepoint Attempt rate', y ='Player Efficiency Rating')

# %%
dataset.plot.scatter(x ='True Shooting(%)', y ='Player Efficiency Rating')

# %%
dataset.plot.scatter(x ='Position', y ='Player Efficiency Rating')

# %%
#Make Heat map to see correlations
correlation = dataset[["Games","Minutes Played","True Shooting(%)", "Threepoint Attempt rate", "Free throw attempt rate"]].corr()
sns.heatmap(correlation, annot=True)

# %%
dataset.describe()
# Out:
#               Age       Games  Minutes Played  True Shooting(%)  \
# count  497.000000  497.000000      497.000000        497.000000
# mean    25.623742   18.456740      414.816901          0.535686
# std      4.054229    8.311394      298.113850          0.136518
# min     19.000000    1.000000        0.000000          0.000000
# 25%     22.000000   12.000000      123.000000          0.499000
# 50%     25.000000   20.000000      414.000000          0.556000
# 75%     28.000000   26.000000      665.000000          0.607000
# max     37.000000   30.000000     1101.000000          1.500000
#
#        Threepoint Attempt rate  Free throw attempt rate  \
# count               497.000000               497.000000
# mean                  0.404726                 0.273698
# std                   0.235149                 0.270665
# min                   0.000000                 0.000000
# 25%                   0.253000                 0.141000
# ...

# %%
sns.pairplot(dataset)

# %%
sns.distplot(dataset["Player Efficiency Rating"])

# %%
sns.distplot(dataset["Free throw attempt rate"])

# %%
sns.distplot(dataset["Threepoint Attempt rate"])

# %%
sns.distplot(dataset["True Shooting(%)"])

# %% [markdown]
# ### we dont need the player and position colunm to test the player efficiency

# %% [markdown]
# dataset.drop(labels=['Player', 'Position'], axis=1,inplace = True)

# %%
dataset
# Out:
#      Age  Games  Minutes Played  True Shooting(%)  Threepoint Attempt rate  \
# 0     21     28           408.0             0.599                    0.000
# 1     24      6            17.0             0.125                    0.250
# 2     27     27           760.0             0.592                    0.000
# 3     23     26           873.0             0.641                    0.015
# 4     35     18           480.0             0.542                    0.298
# ..   ...    ...             ...               ...                      ...
# 492   28     28           823.0             0.559                    0.298
# 493   32     23           592.0             0.597                    0.104
# 494   22     26           901.0             0.598                    0.349
# 495   28     15           361.0             0.569                    0.133
# 496   23     30           586.0             0.722                    0.007
#
#      Free throw attempt rate  Player Efficiency Rating
# ...

# %% [markdown]
# ## 4. Assign dependent and independent variable

# %%
x = dataset.iloc[:,:-1].values

# %%
y = dataset.iloc[:,-1].values

# %%
x
# Out:
# array([[2.10e+01, 2.80e+01, 4.08e+02, 5.99e-01, 0.00e+00, 5.41e-01],
#        [2.40e+01, 6.00e+00, 1.70e+01, 1.25e-01, 2.50e-01, 0.00e+00],
#        [2.70e+01, 2.70e+01, 7.60e+02, 5.92e-01, 0.00e+00, 3.97e-01],
#        ...,
#        [2.20e+01, 2.60e+01, 9.01e+02, 5.98e-01, 3.49e-01, 5.77e-01],
#        [2.80e+01, 1.50e+01, 3.61e+02, 5.69e-01, 1.33e-01, 2.42e-01],
#        [2.30e+01, 3.00e+01, 5.86e+02, 7.22e-01, 7.00e-03, 5.00e-01]])

# %%
y
# Out:
# array([ 15.1,  -6.9,  15.9,  22.7,  15.2, -11.9,  12. ,  14. ,  22.5,
#         21.3,  23.5,   7.5,  17.8,  28.3,  -9.1,  10.3,  13.8,  10.3,
#         14.7,  11.2,  10.8,   8.9,  17.7,  10.6,  10.7,  13.9,  18.2,
#         14.2,  23.4,  12.6,  15.7,  13.1,  11.6,   0.3,  14.8,   8.4,
#         14.7,   9.6,  24.8,  16.7,   8. ,  13.2,  11.5,  13.7,  13. ,
#         14. ,  16.1,  18.3,  12.6,  12.6,  12.6,  -6. ,   9.9,  12.3,
#          4.7,  13.4,   9. ,   5. ,  17.2,  23.4,  17.8,  10.4,  20.3,
#         10.3,  11.4,  16.3,  12. ,  18.3,  10.3,  12.8,  22.3,  33.5,
#         12.9,   5.4,  16.4,  18.8,   8.9,  13.7,  13.5,  24.2,   9.2,
#         38.7,   9.8,  12.1,   2.1,  23.1,  29.8,   8.3,  17.1,   8.2,
#         11.5,  14.8,  10.7,  11.9,   5.3,  16.6,  19. ,  10.1,  19.3,
#         19.8,  13.2,  12.4,  15.1,  10. ,  11.6,  11.5,  10.7,  14.1,
#         25.6,  24.7,  12.2,  11.2,  21.7,  15.9,  18.6,  10.1,  12.7,
# ...

# %% [markdown]
# #5 . Divide the dataset into training set and testing set

# %%
from sklearn. model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split (x,y,test_size=0.2,random_state=4)

# %%
x_train.shape
# Out:
# (397, 6)

# %%
y_train.shape
# Out:
# (397,)

# %%
x_test.shape
# Out:
# (100, 6)

# %%
x_train.shape
# Out:
# (397, 6)

# %% [markdown]
# #6.Import Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
MLR=LinearRegression ()
MLR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
MLR.coef_
# Out:
# array([ 1.23504689e-02, -1.37305966e-01,  9.52748077e-03,  3.22508149e+01,
#        -9.82063362e+00,  7.14315130e-01])

# %%
MLR.intercept_
# Out:
# -2.544107675696143

# %%
y_pred=MLR.predict (x_test)
print (y_pred)
# Out:
# [ 12.78607578  12.92628961  17.14369658  13.98789888   8.48674373
#    2.12309744  12.43263699  11.60768067  18.93825859  18.99149822
#    7.19448398  14.62460834  18.21174456  15.04838106  18.10149047
#   14.71335302   2.71322876   7.65519398  11.74151048  18.11085477
#   14.55178058  11.00219687   6.40654847   0.47033387  14.94922713
#   15.02448607  23.58073851  16.6432977   12.16128858  -2.50688997
#   15.50207142  11.77844234  15.87798802  14.33635838  18.58364371
#   10.7231102   16.5041326    9.40771089   6.47105952  21.51202605
#   10.43273422  16.35105739   8.52901244  11.6871319    3.62338847
#   16.40382982  13.13033536   9.95879102  15.00837445  15.43636464
#   10.19021298   9.67314917  10.08683657  10.91375447  20.79192807
#   12.54491245  15.20988165  10.53557371  12.55761765  16.31441688
#   12.97413338  15.79107032  19.10075647  13.05639867  15.83113491
#   12.32283173  14.38458617  15.73661694  17.3968739   12.19304993
# ...

# %%
y_test
# Out:
# array([ 17. ,  10.7,  13.6,  12.4,   7. ,  -0.8,   7.2,  10. ,  22.3,
#         20.4,   8.3,  20.3,  13.9,   7.5,  17.6,  18.3,   4.5,  10.3,
#          7.4,  19.5,  11.3,  14.2,  10.7,   7.8,  13.9,  17.3,  22.5,
#         16.7,  11.6,  -6.4,  12. ,  11.7,  12.9,  13.4,  27.1,  13.2,
#         12.4,   8.6,   8.1,  20.7,   8.2,  14.7,   6.6,   3.9,   5.8,
#         13.4,  14.6,  15. ,  13.4,  15. ,   8.9,   9.7,  11.9,   6.4,
#         20.7,  12.9,  12. ,  12. ,   9.3,   9.8,  11.2,  18.7,  25.6,
#         10.3,  11.4,  11.7,  12.4,  12.9,  20.9,  14. ,   7.6,  -9.1,
#          3.7,  20.5,  13.2,   6.1,  13.2,  15.1,  13.4,   9.2,  10.7,
#         19.1,  12.2,  11.9,  16.4,   9.8, -10.5,  12. ,  11.2,  14.6,
#         19.1,  26.8,  -5.9,  10.1,  11.7,   8.9,   6.6,  15.2,  10.4,
#         10.3])

# %%
plt.plot (y_test, color="blue")
plt.plot (y_pred, color="red")

# %% [markdown]
# # performance metrics

# %%
from sklearn.metrics import r2_score

r2_score(y_test,y_pred)
# Out:
# 0.7119981063464587

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error (y_test,y_pred)
# Out:
# 11.909793860593858

# %% [markdown]
# #prdecting the values

# %%
MLR.predict([[21,	28,	408.0	,0.599,	0.000	,0.541]])
# Out:
# array([17.46257986])

# %%
plt.figure(figsize= (15, 10))
plt.scatter(y_test, y_pred)
plt.xlabel( 'Actual')
plt.ylabel( 'Predicted ')
plt.title( 'Actual vs. Predicted')
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted')
